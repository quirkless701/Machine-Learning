# %% [markdown]
# ### Feature scaling and Learning Rate (Multi-variable)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_iris
from sklearn.linear_model import LinearRegression as lm

# %%
data = pd.df = pd.read_csv('/home/quirkless/Work/coding ig/machine_learning/Datasets/House price/archive/data.csv')
data.head()
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0       1.50         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0       2.50         3650      9050
# 2  2014-05-02 00:00:00   342000.0       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00   420000.0       3.0       2.25         2000      8030
# 4  2014-05-02 00:00:00   550000.0       4.0       2.50         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
#
# ...

# %%
data.drop(['country', 'date' ,'street', 'statezip', 'city'], axis=1)
# Out:
#              price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0     3.130000e+05       3.0       1.50         1340      7912     1.5
# 1     2.384000e+06       5.0       2.50         3650      9050     2.0
# 2     3.420000e+05       3.0       2.00         1930     11947     1.0
# 3     4.200000e+05       3.0       2.25         2000      8030     1.0
# 4     5.500000e+05       4.0       2.50         1940     10500     1.0
# ...            ...       ...        ...          ...       ...     ...
# 4595  3.081667e+05       3.0       1.75         1510      6360     1.0
# 4596  5.343333e+05       3.0       2.50         1460      7573     2.0
# 4597  4.169042e+05       3.0       2.50         3010      7014     2.0
# 4598  2.034000e+05       4.0       2.00         2090      6630     1.0
# 4599  2.206000e+05       3.0       2.50         1490      8102     2.0
#
#       waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)
x_train.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)
#       2 x_train.head()
#
# File ~/.local/lib/python3.10/site-packages/sklearn/model_selection/_split.py:2559, in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2556 if n_arrays == 0:
#    2557     raise ValueError("At least one array required as input")
# -> 2559 arrays = indexable(*arrays)
#    2561 n_samples = _num_samples(arrays[0])
#    2562 n_train, n_test = _validate_shuffle_split(
#    2563     n_samples, test_size, train_size, default_test_size=0.25
#    2564 )
#
# File ~/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:443, in indexable(*iterables)
#     424 """Make arrays indexable for cross-validation.
#     425
# ...

# %%
x_train.shape
# Out:
# (3680, 17)

# %%
x_test.head()
# Out:
#                      date      price  bedrooms  bathrooms  sqft_living  \
# 3401  2014-06-26 00:00:00   518500.0       3.0       3.50         1590
# 4199  2014-07-09 00:00:00   275000.0       3.0       1.00         1200
# 478   2014-05-12 00:00:00  1200000.0       3.0       1.75         1560
# 924   2014-05-19 00:00:00   477000.0       3.0       2.50         1350
# 2921  2014-06-20 00:00:00   660000.0       4.0       3.25         3030
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# 3401      1102     3.0           0     0          3        1590
# 4199      7800     1.0           0     0          4        1200
# 478       8078     1.5           1     4          4        1560
# 924       2053     3.0           0     0          3        1350
# 2921      9273     2.0           0     0          5        3030
#
#       sqft_basement  yr_built  yr_renovated             street  statezip  \
# 3401              0      2010             0      769 N 74th St  WA 98103
# ...

# %%
x_test.shape
# Out:
# (920, 17)

# %%
model=lm().fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 model=lm().fit(x_train,y_train)
#
# File ~/.local/lib/python3.10/site-packages/sklearn/linear_model/_base.py:648, in LinearRegression.fit(self, X, y, sample_weight)
#     644 n_jobs_ = self.n_jobs
#     646 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> 648 X, y = self._validate_data(
#     649     X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     650 )
#     652 sample_weight = _check_sample_weight(
#     653     sample_weight, X, dtype=X.dtype, only_non_negative=True
#     654 )
#     656 X, y, X_offset, y_offset, X_scale = _preprocess_data(
#     657     X,
#     658     y,
#    (...)
#     661     sample_weight=sample_weight,
#     662 )
#
# ...
